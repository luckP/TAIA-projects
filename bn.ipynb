# %% [markdown]
# # Trabalho de TAIA
# ## Introdução
# Trabalho realizado no ambito da cadeira Tópcos avançados em Inteligencia artificial (TAIA).
# Este trabalho tem como objectivo a implementação de um dos 2 algortmos sugeridos, Gibbs Sampling ou Variable Elimination, e analise dos resultados obtidos.
# Para escolhido para ser implementado o primeiro algoritmo, Gibbs Sampling. <br>
# ----------------- (pequena explicação do algoritmo) -----------------

# %% [markdown]
# ## Implementaçã
# ### Importação dos datasets e das bibliotecas

# %%
import pandas as pd
import bnlearn

# %% [markdown]
# ### Seleção da rede bayesiana e criação do modelo

# %%
bif_file_options = ['sprinkler', 'alarm', 'andes', 'asia', 'pathfinder', 'sachs', 'miserables']
# Loading example dataset
model = bnlearn.import_DAG(bif_file_options[2], CPD=False)
G = bnlearn.plot(model)
# Out:
# [BNLEARN] Loading bif file </Users/lucparada/miniconda3/lib/python3.7/site-packages/bnlearn/DATA/ANDES/andes.bif>
# [BNLEARN][plot] Making plot based on BayesianModel

# %% [markdown]
# ### Gerando as amostrar aleatoria, de acordo com a configuração da rede

# %%
df = bnlearn.sampling(model, n=100)
df.head(5)
# Out:
# [BNLEARN][sampling] Forward sampling for 100 samples..
# ...

# %%
bnlearn.

# %%
model.get_cpds('Rain')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-e6b7fae3f638> in <module>
# ----> 1 model.get_cpds('Rain')
#
# AttributeError: 'dict' object has no attribute 'get_cpds'

# %%
col = 'asia'
df[[col]].groupby(col).size().div(len(df))
# Out:
# asia
# 0    0.0105
# 1    0.9895
# dtype: float64

# %%
# bnlearn.print_CPD(model)

# %%
bnlearn.inference.fit(model)
# Out:
# [BNLEARN][inference] Variable Elimination..
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-fa8a4df75692> in <module>
# ----> 1 bnlearn.inference.fit(model)
#
# ~/miniconda3/lib/python3.7/site-packages/bnlearn/inference.py in fit(model, variables, evidence, verbose)
#      64     model_infer = VariableElimination(model)
#      65     # Computing the probability of Wet Grass given Rain.
# ---> 66     q = model_infer.query(variables=variables, evidence=evidence)
#      67     print(q)
#      68     # for varname in variables: print(q[varname])
#
# ~/miniconda3/lib/python3.7/site-packages/pgmpy/inference/ExactInference.py in query(self, variables, evidence, elimination_order, joint, show_progress)
#     245         """
#     246         common_vars = set(evidence if evidence is not None else []).intersection(
# --> 247             set(variables)
# ...

# %% [markdown]
# <!-- @misc{erdogant2019bnlearn,
#   title={bnlearn},
#   author={Erdogan Taskesen},
#   year={2019},
#   howpublished={\url{https://github.com/erdogant/bnlearn}},
# } -->
